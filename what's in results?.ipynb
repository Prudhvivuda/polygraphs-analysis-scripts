# %%
import os
import json
from collections import defaultdict
import zipfile
import tarfile
import tempfile
import shutil

def is_valid_uuid_folder(dirname):
    """Check if the directory name represents a valid UUID."""
    return len(dirname) == 32 and all(c in "0123456789abcdefABCDEF" for c in dirname)

def extract_info(config_file):
    """Extract information from the configuration file."""
    with open(config_file, 'r') as f:
        config_data = json.load(f)
        return {
            'graph': config_data['network'].get('kind', ''),
            'size': config_data['network'].get('size', ''),
            'op': config_data.get('op', ''),
            'epsilon': config_data.get('epsilon', ''),
            'trials': config_data.get('trials', '')
        }

def get_uuid_folders(directory):
    """Retrieve a list of UUID folders within the given directory."""
    path = os.path.expanduser(directory)
    uuid_folders = []
    try:
        for dirpath, dirnames, _ in os.walk(path):
            for dirname in dirnames:
                folder_path = os.path.join(dirpath, dirname)
                if is_valid_uuid_folder(dirname):
                    uuid_folders.append(folder_path)
    except (FileNotFoundError, PermissionError) as e:
        print(f"Error accessing folder: {e}")
    return uuid_folders

def extract_compressed_file(file_path, extract_to):
    """Extract a compressed file to the specified directory."""
    try:
        if file_path.endswith('.zip'):
            with zipfile.ZipFile(file_path, 'r') as zip_ref:
                zip_ref.extractall(extract_to)
        elif file_path.endswith('.tgz') or file_path.endswith('.tar.gz'):
            try:
                with tarfile.open(file_path, 'r') as tar_ref:
                    tar_ref.extractall(extract_to)
            except tarfile.ReadError as e:
                print(f"Tar read error for '{file_path}': {e}")
                return False
        elif file_path.endswith('.tar'):
            try:
                with tarfile.open(file_path, 'r') as tar_ref:
                    tar_ref.extractall(extract_to)
            except tarfile.ReadError as e:
                print(f"Tar read error for '{file_path}': {e}")
                return False
        else:
            print(f"Unsupported file type: {file_path}")
            return False
        return True
    except Exception as e:
        print(f"Error extracting compressed file '{file_path}': {e}")
        return False

def analyze_directory(directory):
    """Analyze the directory and print the content analysis."""
    uuid_folders = get_uuid_folders(directory)
    print(f"UUID folders found: {len(uuid_folders)} in {directory}\n")
    
    analysis = defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(lambda: defaultdict(int)))))
    
    for folder in uuid_folders:
        config_file = os.path.join(folder, 'configuration.json')
        if os.path.exists(config_file):
            info = extract_info(config_file)
            graph = info['graph']
            size = info['size']
            op = info['op']
            epsilon = info['epsilon']
            trials = info['trials']
            
            analysis[graph][size][op][epsilon][trials] += 1
    
    # Print analysis results
    for graph, sizes in analysis.items():
        print(f"Graph Type '{graph}':")
        for size, ops in sizes.items():
            print(f"  Size '{size}':")
            for op, epsilons in ops.items():
                print(f"    Operation '{op}':")
                for epsilon, trials in epsilons.items():
                    for trial, count in trials.items():
                        print(f"      Epsilon '{epsilon}': {count} occurrences with Trials '{trial}'")
        print('_'*81)
        print()
                        
def process_compressed_file(file_path, directory):
    """Process a compressed file."""
    print(f"Found a compressed file: {file_path}")
    with tempfile.TemporaryDirectory() as temp_dir:
        # print(f"Extracting {file_path} to {temp_dir}...")
        if extract_compressed_file(file_path, temp_dir):
            # print(f"Extracted {file_path} successfully.")
            analyze_directory(temp_dir)
        else:
            print(f"Failed to extract {file_path}.")
    

# Directory to analyze
# directory = '/Users/prudhvivuda/Documents/polygraphs-cache/1/'
directory = '/Users/prudhvivuda/Documents/p/'

analyze_directory(directory)

for root, _, files in os.walk(directory):
    for file in files:
        file_path = os.path.join(root, file)
        if file_path.endswith(('.zip', '.tgz', '.tar.gz', '.tar')):
            process_compressed_file(file_path, directory)
# Out:
# UUID folders found: 266 in /Users/prudhvivuda/Documents/p/
#
# Graph Type 'wattsstrogatz':
#   Size '8':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Graph Type 'barabasialbert':
#   Size '8':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 10 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Graph Type 'snap':
#   Size 'None':
#     Operation 'BalaGoyalOp':
#       Epsilon '0.001': 5 occurrences with Trials '10'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Polarization/2022-02-17-003.zip
# UUID folders found: 82 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpbl0r4h7z
#
# Graph Type 'star':
#   Size '4':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '4'
#       Epsilon '0.1': 3 occurrences with Trials '64'
#       Epsilon '0.01': 3 occurrences with Trials '4'
#       Epsilon '0.01': 3 occurrences with Trials '64'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#   Size '64':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.01': 3 occurrences with Trials '64'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '4'
#       Epsilon '0.1': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '64'
#       Epsilon '0.1': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '4'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '64'
#       Epsilon '0.01': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.001': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.1': 3 occurrences with Trials '64'
#       Epsilon '0.1': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '4'
# _________________________________________________________________________________
#
# Graph Type 'complete':
#   Size '16':
#     Operation 'BalaGoyalOp':
#       Epsilon '0.01': 1 occurrences with Trials '10'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Polarization/2022-02-16.zip
# UUID folders found: 81 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmplirx9kp3
#
# Graph Type 'complete':
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.01': 3 occurrences with Trials '4'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '4'
#       Epsilon '0.1': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '64'
#   Size '64':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.1': 3 occurrences with Trials '64'
#       Epsilon '0.1': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '4'
#       Epsilon '0.01': 3 occurrences with Trials '64'
#   Size '4':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.01': 3 occurrences with Trials '4'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '4'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '4'
#       Epsilon '0.1': 3 occurrences with Trials '16'
#       Epsilon '0.1': 3 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Polarization/2022-02-18-001.zip
# UUID folders found: 243 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpddgn1n1u
#
# Graph Type 'complete':
#   Size '4':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.01': 9 occurrences with Trials '4'
#       Epsilon '0.01': 9 occurrences with Trials '64'
#       Epsilon '0.01': 9 occurrences with Trials '16'
#       Epsilon '0.001': 9 occurrences with Trials '16'
#       Epsilon '0.001': 9 occurrences with Trials '64'
#       Epsilon '0.001': 9 occurrences with Trials '4'
#       Epsilon '0.1': 9 occurrences with Trials '64'
#       Epsilon '0.1': 9 occurrences with Trials '4'
#       Epsilon '0.1': 9 occurrences with Trials '16'
#   Size '64':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 9 occurrences with Trials '16'
#       Epsilon '0.001': 9 occurrences with Trials '64'
#       Epsilon '0.001': 9 occurrences with Trials '4'
#       Epsilon '0.01': 9 occurrences with Trials '4'
#       Epsilon '0.01': 9 occurrences with Trials '16'
#       Epsilon '0.01': 9 occurrences with Trials '64'
#       Epsilon '0.1': 9 occurrences with Trials '4'
#       Epsilon '0.1': 9 occurrences with Trials '64'
#       Epsilon '0.1': 9 occurrences with Trials '16'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 9 occurrences with Trials '64'
#       Epsilon '0.001': 9 occurrences with Trials '16'
#       Epsilon '0.001': 9 occurrences with Trials '4'
#       Epsilon '0.01': 9 occurrences with Trials '64'
#       Epsilon '0.01': 9 occurrences with Trials '4'
#       Epsilon '0.01': 9 occurrences with Trials '16'
#       Epsilon '0.1': 9 occurrences with Trials '4'
#       Epsilon '0.1': 9 occurrences with Trials '16'
#       Epsilon '0.1': 9 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Polarization/2022-02-19-004.zip
# UUID folders found: 486 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmp7kkkcd00
#
# Graph Type 'complete':
#   Size '64':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.01': 18 occurrences with Trials '4'
#       Epsilon '0.01': 18 occurrences with Trials '16'
#       Epsilon '0.01': 18 occurrences with Trials '64'
#       Epsilon '0.1': 18 occurrences with Trials '4'
#       Epsilon '0.1': 18 occurrences with Trials '16'
#       Epsilon '0.1': 18 occurrences with Trials '64'
#       Epsilon '0.001': 18 occurrences with Trials '64'
#       Epsilon '0.001': 18 occurrences with Trials '4'
#       Epsilon '0.001': 18 occurrences with Trials '16'
#   Size '4':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 18 occurrences with Trials '64'
#       Epsilon '0.001': 18 occurrences with Trials '4'
#       Epsilon '0.001': 18 occurrences with Trials '16'
#       Epsilon '0.01': 18 occurrences with Trials '16'
#       Epsilon '0.01': 18 occurrences with Trials '64'
#       Epsilon '0.01': 18 occurrences with Trials '4'
#       Epsilon '0.1': 18 occurrences with Trials '4'
#       Epsilon '0.1': 18 occurrences with Trials '64'
#       Epsilon '0.1': 18 occurrences with Trials '16'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.1': 18 occurrences with Trials '4'
#       Epsilon '0.1': 18 occurrences with Trials '64'
#       Epsilon '0.1': 18 occurrences with Trials '16'
#       Epsilon '0.01': 18 occurrences with Trials '4'
#       Epsilon '0.01': 18 occurrences with Trials '16'
#       Epsilon '0.01': 18 occurrences with Trials '64'
#       Epsilon '0.001': 18 occurrences with Trials '16'
#       Epsilon '0.001': 18 occurrences with Trials '64'
#       Epsilon '0.001': 18 occurrences with Trials '4'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Workshop 2/testimonials-001.tgz
# UUID folders found: 338 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmp19cziugo
#
# Graph Type 'complete':
#   Size '16':
#     Operation 'UnreliableNetworkBasicGullibleOpBinomial':
#       Epsilon '0.001': 16 occurrences with Trials '16'
#       Epsilon '0.001': 15 occurrences with Trials '64'
#       Epsilon '0.01': 19 occurrences with Trials '64'
#       Epsilon '0.01': 15 occurrences with Trials '16'
#     Operation 'UnreliableNetworkBasicAlignedOpBinomial':
#       Epsilon '0.01': 16 occurrences with Trials '64'
#       Epsilon '0.01': 15 occurrences with Trials '16'
#       Epsilon '0.001': 15 occurrences with Trials '16'
#       Epsilon '0.001': 15 occurrences with Trials '64'
#     Operation 'UnreliableNetworkBasicAlignedOp':
#       Epsilon '0.001': 10 occurrences with Trials '16'
#     Operation 'BalaGoyalOp':
#       Epsilon '0.01': 5 occurrences with Trials '16'
#       Epsilon '0.01': 5 occurrences with Trials '64'
#       Epsilon '0.001': 10 occurrences with Trials '64'
#       Epsilon '0.001': 5 occurrences with Trials '16'
#   Size '64':
#     Operation 'UnreliableNetworkBasicAlignedOpBinomial':
#       Epsilon '0.001': 15 occurrences with Trials '16'
#       Epsilon '0.001': 15 occurrences with Trials '64'
#       Epsilon '0.01': 15 occurrences with Trials '16'
#       Epsilon '0.01': 15 occurrences with Trials '64'
#     Operation 'UnreliableNetworkBasicGullibleOpBinomial':
#       Epsilon '0.01': 15 occurrences with Trials '64'
#       Epsilon '0.01': 15 occurrences with Trials '16'
#       Epsilon '0.001': 15 occurrences with Trials '64'
#       Epsilon '0.001': 15 occurrences with Trials '16'
#     Operation 'UnreliableNetworkBasicAlignedOp':
#       Epsilon '0.001': 5 occurrences with Trials '16'
#     Operation 'BalaGoyalOp':
#       Epsilon '0.01': 5 occurrences with Trials '64'
#       Epsilon '0.01': 5 occurrences with Trials '16'
#       Epsilon '0.001': 5 occurrences with Trials '64'
#       Epsilon '0.001': 5 occurrences with Trials '16'
#     Operation 'UnreliableNetworkBasicGullibleNegativeEpsOp':
#       Epsilon '0.001': 15 occurrences with Trials '64'
#     Operation 'UnreliableNetworkBasicAlignedNegativeEpsOp':
#       Epsilon '0.001': 17 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Workshop 2/workshop_2.tgz
# UUID folders found: 0 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpv259eh9i
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Workshop 2/zollman-b.tgz
# UUID folders found: 8032 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmp18_rsi43
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Workshop 2/distance.tgz
# UUID folders found: 37 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpb2r078kz
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Workshop 2/ba-ws.tgz
# UUID folders found: 25 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpdz2cu61h
#
# Graph Type 'wattsstrogatz':
#   Size '8':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Graph Type 'barabasialbert':
#   Size '8':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 10 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Testimonials/2023-04-19.zip
# UUID folders found: 77 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmp53ixdp7_
#
# Graph Type 'complete':
#   Size '16':
#     Operation 'UnreliableNetworkBasicUnalignedOp':
#       Epsilon '0.001': 10 occurrences with Trials '16'
#       Epsilon '0.001': 10 occurrences with Trials '64'
#       Epsilon '0.01': 10 occurrences with Trials '16'
#       Epsilon '0.01': 10 occurrences with Trials '64'
#   Size '64':
#     Operation 'UnreliableNetworkBasicUnalignedOp':
#       Epsilon '0.001': 9 occurrences with Trials '16'
#       Epsilon '0.001': 9 occurrences with Trials '64'
#       Epsilon '0.01': 10 occurrences with Trials '16'
#       Epsilon '0.01': 9 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Testimonials/2023-03-23.zip
# UUID folders found: 30 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpj7x5jux4
#
# Graph Type 'complete':
#   Size '16':
#     Operation 'UnreliableNetworkBasicGullibleOp':
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '64'
#   Size '64':
#     Operation 'UnreliableNetworkBasicGullibleOp':
#       Epsilon '0.001': 9 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Testimonials/2023-04-04.zip
# UUID folders found: 24 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpcra3y_6w
#
# Graph Type 'complete':
#   Size '16':
#     Operation 'UnreliableNetworkBasicAlignedOp':
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.01': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '16'
#   Size '64':
#     Operation 'UnreliableNetworkBasicAlignedOp':
#       Epsilon '0.01': 3 occurrences with Trials '64'
#       Epsilon '0.01': 3 occurrences with Trials '16'
#       Epsilon '0.001': 3 occurrences with Trials '64'
#       Epsilon '0.001': 3 occurrences with Trials '16'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Distance/2022-10-07 d squared.zip
# UUID folders found: 18 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpz5d10lj4
#
# Graph Type 'complete':
#   Size '16':
#     Operation 'OConnorWeatherallSquareDistanceOp':
#       Epsilon '0.01': 1 occurrences with Trials '64'
#       Epsilon '0.01': 1 occurrences with Trials '4'
#       Epsilon '0.01': 1 occurrences with Trials '16'
#       Epsilon '0.001': 1 occurrences with Trials '64'
#       Epsilon '0.001': 1 occurrences with Trials '16'
#       Epsilon '0.001': 1 occurrences with Trials '4'
#       Epsilon '0.1': 1 occurrences with Trials '16'
#       Epsilon '0.1': 1 occurrences with Trials '4'
#       Epsilon '0.1': 1 occurrences with Trials '64'
#   Size '64':
#     Operation 'OConnorWeatherallSquareDistanceOp':
#       Epsilon '0.01': 1 occurrences with Trials '64'
#       Epsilon '0.01': 1 occurrences with Trials '4'
#       Epsilon '0.01': 1 occurrences with Trials '16'
#       Epsilon '0.1': 1 occurrences with Trials '64'
#       Epsilon '0.1': 1 occurrences with Trials '16'
#       Epsilon '0.1': 1 occurrences with Trials '4'
#       Epsilon '0.001': 1 occurrences with Trials '16'
#       Epsilon '0.001': 1 occurrences with Trials '4'
#       Epsilon '0.001': 1 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Distance/2022-10-05 - root d.zip
# UUID folders found: 19 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpca29i8og
#
# Graph Type 'complete':
#   Size '64':
#     Operation 'OConnorWeatherallSquareRootDistanceOp':
#       Epsilon '0.001': 1 occurrences with Trials '64'
#       Epsilon '0.001': 1 occurrences with Trials '16'
#       Epsilon '0.001': 1 occurrences with Trials '4'
#       Epsilon '0.01': 1 occurrences with Trials '4'
#       Epsilon '0.01': 1 occurrences with Trials '64'
#       Epsilon '0.01': 1 occurrences with Trials '16'
#       Epsilon '0.1': 1 occurrences with Trials '4'
#       Epsilon '0.1': 1 occurrences with Trials '16'
#       Epsilon '0.1': 1 occurrences with Trials '64'
#   Size '16':
#     Operation 'OConnorWeatherallSquareRootDistanceOp':
#       Epsilon '0.1': 1 occurrences with Trials '64'
#       Epsilon '0.1': 1 occurrences with Trials '16'
#       Epsilon '0.1': 1 occurrences with Trials '4'
#       Epsilon '0.001': 1 occurrences with Trials '16'
#       Epsilon '0.001': 1 occurrences with Trials '64'
#       Epsilon '0.001': 1 occurrences with Trials '4'
#       Epsilon '0.01': 1 occurrences with Trials '16'
#       Epsilon '0.01': 1 occurrences with Trials '4'
#       Epsilon '0.01': 1 occurrences with Trials '64'
#   Size '8':
#     Operation 'OConnorWeatherallSquareRootDistanceOp':
#       Epsilon '0.01': 1 occurrences with Trials '10'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Groups/LiveJournal1 2023-03-07.zip
# UUID folders found: 1 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmplz1yy5ig
#
# Graph Type 'snap':
#   Size 'None':
#     Operation 'BalaGoyalOp':
#       Epsilon '0.001': 1 occurrences with Trials '10'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Large-Scale Sims/2022-10-12 large sims.zip
# UUID folders found: 2 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmp4leakdgw
#
# Graph Type 'snap':
#   Size 'None':
#     Operation 'BalaGoyalOp':
#       Epsilon '0.001': 2 occurrences with Trials '10'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Large-Scale Sims/2022-10-18 Ego-Twitter.zip
# UUID folders found: 2 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmp3gnksm0z
#
# Graph Type 'snap':
#   Size 'None':
#     Operation 'BalaGoyalOp':
#       Epsilon '0.001': 2 occurrences with Trials '10'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Large-Scale Sims/2023-01-20 Email-EU-Core_no_selfloop.tgz
# UUID folders found: 5 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpdq634a5o
#
# Graph Type 'snap':
#   Size 'None':
#     Operation 'BalaGoyalOp':
#       Epsilon '0.001': 5 occurrences with Trials '10'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Zollman Effect/Single Density BA-WS/ba-ws.tgz
# UUID folders found: 25 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmpx3q3uat_
#
# Graph Type 'wattsstrogatz':
#   Size '8':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Graph Type 'barabasialbert':
#   Size '8':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 5 occurrences with Trials '64'
#   Size '16':
#     Operation 'OConnorWeatherallOp':
#       Epsilon '0.001': 10 occurrences with Trials '64'
# _________________________________________________________________________________
#
# Found a compressed file: /Users/prudhvivuda/Documents/p/Zollman Effect/summary/paths.tgz
# UUID folders found: 0 in /var/folders/4l/bv2lyg350p1fysck60fq0kgw0000gn/T/tmp408r3qt_
